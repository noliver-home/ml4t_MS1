# %%
#zipline_test
#This notebook is deliverable #1 for ML4T Milestone 1
#Milestone 1 takes me through installing miniconda, installing zipline, loading data from Quandl, and
#running a simple trading tutorial (Dual Moving Average).
#See https://zipline.ml4trading.io/beginner-tutorial
#and https://liveproject.manning.com/module/199_2_1/algorithmic-trading-with-machine-learning/1--setting-up-your-environment-and-sourcing-the-data/1-1-workflow%3a-setting-up-your-environment-and-sourcing-the-data?
#Assume that data from Quandl has been downloaded "out of band", i.e., after getting zipline installed, running
#zipline ingest -b Quandl
#This data is stored under C:\Users\<me>\.zipline
import zipline

# %%
#load the zipline extension
# %load_ext zipline
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %%
# %%zipline --start 2014-1-1 --end 2018-1-1 --no-benchmark -o dma1.pickle
#
# #run the DMA crossover example from https://zipline.ml4trading.io/beginner-tutorial.
# #NOTE that when this example is run from a Jupyter notebook, the cell in which zipline is run (i.e., this one),
# #must start with the %%zipline magic command, otherwise the error "magic %%zipline not found" will occur.
#
# from zipline.api import order_target, record, symbol
# import pandas as pd
# import matplotlib.pyplot as plt
#
# ######################################################
# #zipline initialize method. I don't think anything other than this is required.
# def initialize(context):
#     context.i = 0
#     context.asset = symbol("AAPL")
#
# #####################################################
# #zipline handle_data method, called for each
# def handle_data(context, data):
#     # Skip first 300 days to get full windows
#     context.i += 1
#     if context.i < 300:
#         return
#
#     # Compute averages
#     # data.history() has to be called with the same params
#     # from above and returns a pandas dataframe.
#     short_mavg = data.history(context.asset, 'price', bar_count=100, frequency="1d").mean()
#     long_mavg = data.history(context.asset, 'price', bar_count=300, frequency="1d").mean()
#
#     # Trading logic
#     #If current 100-day MAVG is higher than the 300-day MAVG, make the portfolio have 300 shares
#     if short_mavg > long_mavg:
#         # order_target orders as many shares as needed to
#         # achieve the desired number of shares.
#         order_target(context.asset, 100)
#     #If current 100-day MAVG is lower than the 300-day MAVG, make the portfolio have 0 shares
#     elif short_mavg < long_mavg:
#         order_target(context.asset, 0)
#
#     # Save values for later inspection
#     record(AAPL=data.current(context.asset, 'price'),
#            short_mavg=short_mavg,
#            long_mavg=long_mavg)
#
# #Zipline method analyze: called after all the data has been processed.
# #In this case, use MatPlotLib to display a chart
#
# def analyze(context, perf):
#     fig = plt.figure()
#     ax1 = fig.add_subplot(211)
#     perf.portfolio_value.plot(ax=ax1)
#     ax1.set_ylabel('portfolio value in $')
#
#     ax2 = fig.add_subplot(212)
#     perf['AAPL'].plot(ax=ax2)
#     perf[['short_mavg', 'long_mavg']].plot(ax=ax2)
#
#     perf_trans = perf.loc[[t != [] for t in perf.transactions]]
#     buys = perf_trans.loc[[t[0]['amount'] > 0 for t in perf_trans.transactions]]
#     sells = perf_trans.loc[
#         [t[0]['amount'] < 0 for t in perf_trans.transactions]]
#     ax2.plot(buys.index, perf.short_mavg.loc[buys.index],
#              '^', markersize=10, color='m')
#     ax2.plot(sells.index, perf.short_mavg.loc[sells.index],
#              'v', markersize=10, color='k')
#     ax2.set_ylabel('price in $')
#     plt.legend(loc=0)
#     plt.show()
#
# #When this code is run, npdivide errors occur, but the code still seems to work.
# Out:
# C:\Users\noliver\.conda\envs\ml4t\lib\site-packages\empyrical\stats.py:706: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(
# C:\Users\noliver\.conda\envs\ml4t\lib\site-packages\empyrical\stats.py:797: RuntimeWarning: invalid value encountered in true_divide
#   np.divide(average_annual_return, annualized_downside_risk, out=out)
#                                         period_open              period_close  \
# 2014-01-02 21:00:00+00:00 2014-01-02 14:31:00+00:00 2014-01-02 21:00:00+00:00
# 2014-01-03 21:00:00+00:00 2014-01-03 14:31:00+00:00 2014-01-03 21:00:00+00:00
# 2014-01-06 21:00:00+00:00 2014-01-06 14:31:00+00:00 2014-01-06 21:00:00+00:00
# 2014-01-07 21:00:00+00:00 2014-01-07 14:31:00+00:00 2014-01-07 21:00:00+00:00
# 2014-01-08 21:00:00+00:00 2014-01-08 14:31:00+00:00 2014-01-08 21:00:00+00:00
# ...                                             ...                       ...
# 2017-12-22 21:00:00+00:00 2017-12-22 14:31:00+00:00 2017-12-22 21:00:00+00:00
# ...
